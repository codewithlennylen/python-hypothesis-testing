# %%
favorites = ['books', 'cats', 'science']
favorites
# Out:
# ['books', 'cats', 'science']

# %%
favorites[1]
# Out:
# 'cats'

# %%
favorites[-1]
# Out:
# 'science'

# %%
favorites[-1][-2] # expect 'c'
# Out:
# 'c'

# %%
favorites[-1]='robots'
favorites
# Out:
# ['books', 'cats', 'robots']

# %%
favorites.append('rockets')
favorites
# Out:
# ['books', 'cats', 'robots', 'rockets', 'rockets', 'rockets']

# %%
more_favorites = ['food','movies']
favorite_things = favorites + more_favorites

# %%
favorite_things
# Out:
# ['books', 'cats', 'robots', 'rockets', 'rockets', 'rockets', 'food', 'movies']

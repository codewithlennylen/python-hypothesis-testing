# %%
favorites = ['books', 'cats', 'science']

# %%
example_dict = {"A":1, "B":2, "C":3}
example_dict
# Out:
# {'A': 1, 'B': 2, 'C': 3}

# %%
example_dict.keys()
# Out:
# dict_keys(['A', 'B', 'C'])

# %%
example_dict.values()
# Out:
# dict_values([1, 2, 3])

# %%
example_dict["D"] = 4

# %%
import random

oft = {}

for thing in favorites:
    oft[thing] = random.randint(0,1)

oft
# Out:
# {'books': 0, 'cats': 0, 'science': 0}
